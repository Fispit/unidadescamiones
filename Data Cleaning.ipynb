# %%
import pandas as pd
import matplotlib.path as mplPath
import numpy as np
import ast

# %%
#importing the data
data_df=pd.read_csv("prueba_fetchdata_metrobus.csv")
data_df
# Out:
#       id         date_updated  vehicle_id  vehicle_label  \
# 0      0  2021-01-27 18:00:02         170            112
# 1      1  2021-01-27 18:00:02         177            119
# 2      2  2021-01-27 18:00:02        1286            219
# 3      3  2021-01-27 18:00:02        1302            235
# 4      4  2021-01-27 18:00:02         361            303
# ..   ...                  ...         ...            ...
# 202  202  2021-01-27 18:00:02        1238           2347
# 203  203  2021-01-27 18:00:02        1024           2351
# 204  204  2021-01-27 18:00:02       10002           2358
# 205  205  2021-01-27 18:00:02        1232           2363
# 206  206  2021-01-27 18:00:02        1235           2366
#
#      vehicle_current_status  position_latitude  position_longitude  \
# 0                         2          19.317499          -99.187798
# 1                         1          19.292601          -99.177498
# 2                         2          19.450100          -99.110100
# ...

# %%
#Removing the trip IDs and dates, they do not contribute to position
data_df=data_df.drop(columns=["trip_id","trip_start_date","trip_route_id"])
#Removing the 0 latitude data points
data_df=data_df.loc[data_df["position_latitude"]>0]

# %%
data_df
# Out:
#       id         date_updated  vehicle_id  vehicle_label  \
# 0      0  2021-01-27 18:00:02         170            112
# 1      1  2021-01-27 18:00:02         177            119
# 2      2  2021-01-27 18:00:02        1286            219
# 3      3  2021-01-27 18:00:02        1302            235
# 4      4  2021-01-27 18:00:02         361            303
# ..   ...                  ...         ...            ...
# 202  202  2021-01-27 18:00:02        1238           2347
# 203  203  2021-01-27 18:00:02        1024           2351
# 204  204  2021-01-27 18:00:02       10002           2358
# 205  205  2021-01-27 18:00:02        1232           2363
# 206  206  2021-01-27 18:00:02        1235           2366
#
#      vehicle_current_status  position_latitude  position_longitude  \
# 0                         2          19.317499          -99.187798
# 1                         1          19.292601          -99.177498
# 2                         2          19.450100          -99.110100
# ...

# %%
data_df.to_csv("Cleaned-data.csv",index=False)

# %%
test=pd.read_csv("limite-de-las-alcaldias2.csv")

# %%
test
# Out:
#     id                nomgeo  cve_mun  cve_ent  cvegeo  gid  \
# 0    0            Xochimilco       13        9    9013    5
# 1    1            Cuauhtémoc       15        9    9015   13
# 2    2             Iztacalco        6        9    9006    2
# 3    3         ÁlvaroObregón       10        9    9010    4
# 4    4              Coyoacán        3        9    9003    7
# 5    5               Tlalpan       12        9    9012    8
# 6    6       GustavoA.Madero        5        9    9005   12
# 7    7            Iztapalapa        7        9    9007   15
# 8    8          Azcapotzalco        2        9    9002    1
# 9    9             MilpaAlta        9        9    9009    3
# 10  10    VenustianoCarranza       17        9    9017    6
# 11  11          BenitoJuárez       14        9    9014    9
# 12  12   CuajimalpadeMorelos        4        9    9004   10
# 13  13         MiguelHidalgo       16        9    9016   11
# 14  14  LaMagdalenaContreras        8        9    9008   14
# ...

# %%
#Applying functions to only get the geoshape points as an array
test['geo_shape']=test['geo_shape'].map(lambda x: x.lstrip('{"type": "Polygon", "coordinates": ').rstrip('}'))
test['geo_shape'] = test['geo_shape'].map(lambda x: x[1:-1])

# %%
test
# Out:
#     id                nomgeo  cve_mun  cve_ent  cvegeo  gid  \
# 0    0            Xochimilco       13        9    9013    5
# 1    1            Cuauhtémoc       15        9    9015   13
# 2    2             Iztacalco        6        9    9006    2
# 3    3         ÁlvaroObregón       10        9    9010    4
# 4    4              Coyoacán        3        9    9003    7
# 5    5               Tlalpan       12        9    9012    8
# 6    6       GustavoA.Madero        5        9    9005   12
# 7    7            Iztapalapa        7        9    9007   15
# 8    8          Azcapotzalco        2        9    9002    1
# 9    9             MilpaAlta        9        9    9009    3
# 10  10    VenustianoCarranza       17        9    9017    6
# 11  11          BenitoJuárez       14        9    9014    9
# 12  12   CuajimalpadeMorelos        4        9    9004   10
# 13  13         MiguelHidalgo       16        9    9016   11
# 14  14  LaMagdalenaContreras        8        9    9008   14
# ...

# %%
#Example on how to convert the text into an array
# test2=ast.literal_eval(test.geo_shape[1])
# poly_path = mplPath.Path(np.array(test2))
# point = (-99.1289, 19.4598)
# print(point, " is in polygon: ", poly_path.contains_point(point))

# %%
alcaldias=test[["id","nomgeo","geo_shape"]]
alcaldias=alcaldias.rename(columns={"nomgeo":"alcaldia"})
alcaldias
# Out:
#     id              alcaldia  \
# 0    0            Xochimilco
# 1    1            Cuauhtémoc
# 2    2             Iztacalco
# 3    3         ÁlvaroObregón
# 4    4              Coyoacán
# 5    5               Tlalpan
# 6    6       GustavoA.Madero
# 7    7            Iztapalapa
# 8    8          Azcapotzalco
# 9    9             MilpaAlta
# 10  10    VenustianoCarranza
# 11  11          BenitoJuárez
# 12  12   CuajimalpadeMorelos
# 13  13         MiguelHidalgo
# 14  14  LaMagdalenaContreras
# 15  15               Tláhuac
#
#                                             geo_shape
# 0   [[-99.09869648999997,19.319641419999197],[-99....
# 1   [[-99.12919093999987,19.462466519999197],[-99....
# 2   [[-99.05583625999998,19.421961229999095],[-99....
# 3   [[-99.18870661999989,19.394747649999097],[-99....
# 4   [[-99.13923187999987,19.356865289999092],[-99....
# 5   [[-99.19628607999987,19.302278169999095],[-99....
# 6   [[-99.11859756999998,19.584461719999098],[-99....
# ...

# %%
alcaldias.to_csv("alcaldias.csv",index=False)

# %%
test2=data_df
test2["alcaldia"]=""

# %%
#funcion para incluir la alcaldia en los datos de camiones
def loc_alcaldias(x):
    lat=x.position_latitude
    lon=x.position_longitude
    
    for x in range(0,len(alcaldias.id)):
        polygon=ast.literal_eval(alcaldias.geo_shape[x])
        poly_path = mplPath.Path(np.array(polygon))
        point = (lon, lat)
        inalc=poly_path.contains_point(point)
        if inalc:
            return alcaldias.alcaldia[x]

# %%
test2["alcaldia"]=test2.apply(loc_alcaldias,axis=1)

# %%
#seeing the results of the apply
test2
# Out:
#       id         date_updated  vehicle_id  vehicle_label  \
# 0      0  2021-01-27 18:00:02         170            112
# 1      1  2021-01-27 18:00:02         177            119
# 2      2  2021-01-27 18:00:02        1286            219
# 3      3  2021-01-27 18:00:02        1302            235
# 4      4  2021-01-27 18:00:02         361            303
# ..   ...                  ...         ...            ...
# 202  202  2021-01-27 18:00:02        1238           2347
# 203  203  2021-01-27 18:00:02        1024           2351
# 204  204  2021-01-27 18:00:02       10002           2358
# 205  205  2021-01-27 18:00:02        1232           2363
# 206  206  2021-01-27 18:00:02        1235           2366
#
#      vehicle_current_status  position_latitude  position_longitude  \
# 0                         2          19.317499          -99.187798
# 1                         1          19.292601          -99.177498
# 2                         2          19.450100          -99.110100
# ...

# %%
test2["alcaldia"].unique()
# Out:
# array(['Coyoacán', 'Tlalpan', 'VenustianoCarranza', 'Iztapalapa',
#        'GustavoA.Madero', 'Cuauhtémoc', 'BenitoJuárez', 'Azcapotzalco',
#        'MiguelHidalgo', 'Iztacalco', 'ÁlvaroObregón'], dtype=object)

# %%
test2.to_csv("Cleaned-data.csv",index=False)

# %% [markdown]
# ## Work on updating the database.

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import json
import requests

# %%
engine = create_engine('postgresql://postgres:testpassword@unidades-db.cuzb9dl0k6mc.us-east-2.rds.amazonaws.com:5432/postgres')

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
viajes=Base.classes.viajes

# %%
import urllib
limit=25
url = f'https://datos.cdmx.gob.mx/api/3/action/datastore_search?resource_id=ad360a0e-b42f-482c-af12-1fd72140032e&limit={limit}'  
fileobj = urllib.request.urlopen(url)
newdata=json.load(fileobj)

# %%
newdata['result']['records'][2]
records=newdata['result']['records']
newdata['result']['records'][2]
# Out:
# {'_id': 3,
#  'id': 2,
#  'date_updated': '2021-01-27T18:00:02',
#  'vehicle_id': 1286,
#  'vehicle_label': 219,
#  'vehicle_current_status': 2,
#  'position_latitude': 19.45009994506836,
#  'position_longitude': -99.11009979248048,
#  'geographic_point': '19.4500999451,-99.1100997925',
#  'position_speed': 5,
#  'position_odometer': 0,
#  'trip_schedule_relationship': 0,
#  'trip_id': 9678929,
#  'trip_start_date': 20200428,
#  'trip_route_id': 161}

# %%
session = Session(engine)
first_row = session.query(viajes).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x173528350b8>,
#  'id': 0,
#  'date_updated': '2021-01-27 18:00:02',
#  'vehicle_id': 170,
#  'vehicle_label': 112,
#  'position_latitude': 19.3174991607666,
#  'geographic_point': '19.3174991608,-99.1877975464',
#  'position_odometer': 231,
#  'alcaldia': 'Coyoacán',
#  'vehicle_current_status': 2,
#  'position_longitude': -99.18779754638672,
#  'position_speed': 16,
#  'trip_schedule_relationship': 2}

# %%
querystring=f"select * from alcaldias "
alcaldias=engine.execute(querystring)
jsondata=[]
for element in alcaldias:
    getdict={}
    getdict['id']= element.id
    getdict['alcaldia']= element.alcaldia
    getdict['geo_shape']= element.geo_shape
    jsondata.append(getdict)

# %%
def loc_alcaldias_json(x):
    lat=x["position_latitude"]
    lon=x["position_longitude"]
    
    for x in jsondata:
        
        polygon=ast.literal_eval(x["geo_shape"])
        poly_path = mplPath.Path(np.array(polygon))
        point = (lon, lat)
        inalc=poly_path.contains_point(point)
        if inalc:
            return x["alcaldia"]

# %%
querystring="select max(id) as id from viajes"
getmaxid=engine.execute(querystring)
for x in getmaxid:
    idnum=x[0]+1
idnum
# Out:
# 206

# %%
session=Session(engine)
for x in records:
    uploadclass=viajes()
    uploadclass.id=idnum
    uploadclass.vehicle_id=x["vehicle_id"]
    uploadclass.vehicle_current_status=x["vehicle_current_status"]
    uploadclass.position_longitude=x["position_longitude"]
    uploadclass.position_speed=x["position_speed"]
    uploadclass.trip_schedule_relationship=x["trip_schedule_relationship"]
    uploadclass.vehicle_label=x["vehicle_label"]
    uploadclass.date_updated=x["date_updated"]
    uploadclass.position_latitude=x["position_latitude"]
    uploadclass.geographic_point=x["geographic_point"]
    uploadclass.position_odometer=x["position_odometer"]
    uploadclass.alcaldia=loc_alcaldias_json(x)
    idnum=idnum+1
    session.add(uploadclass)
session.commit()
session.close()

# %%
viajes.alcaldia
